# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
from astropy.nddata import CCDData
from astropy.stats import mad_std

from ccdproc import ImageFileCollection
import ccdproc

# %%
import arya
plt.rcParams["figure.dpi"] = 300

# %%
from pathlib import Path

# %%
object_name = "OB0001"

# %%
filters = ["Sloan_g", "Sloan_r", "Sloan_i"]

# %%
data_dir = Path(f"{object_name}")

# %%
from convenience_functions import show_image, show_images, show_image_residual

# %%
img_g_auto = CCDData.read("OB0001_b/reduced/GTC73-23A_0001_Sloan_g_pho_NOSKY.fits")

# %%
img_g_auto_initial = CCDData.read("OB0001_b/reduced/GTC73-23A_0001_Sloan_g_stacked_SKY.fits")

# %%
img_g_me = CCDData.read("OB0001/reduced/stacked_g.fits")

# %%
img_g_yasone = CCDData.read("stacked_0_9/GTC73-23A_0001_Sloan_g_20230708_NOSKY_BBI.fits")

# %%
show_images([img_g_me, img_g_auto, img_g_yasone], figscale=5)

# %%
np.median(img_g_auto_initial.data / img_g_me[1:, 1:].data)

# %%
show_image_residual(img_g_auto_initial.data / 30_000, img_g_me[1:, 1:].data * 10.1559 / 30_000)

# %%
show_image_residual(img_g_auto.data, img_g_yasone.data)

# %%
BPM = CCDData.read("BPM_OSIRIS_PLUS.fits")

# %%
img_selection = "[28:2060,230:2026]"
overscan_selection = "[9:24,1:2056]"

# %%
def trim_image(image):
    return ccdproc.trim_image(CCDData(image), fits_section=img_selection)

# %%
show_image(BPM)

# %%
show_image(trim_image(BPM))
